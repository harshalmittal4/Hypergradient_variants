# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %%
sgd_adam = pd.read_csv('test/logreg/+1e-03_+1e-03/sgd_HdAdam.csv')
sgd_hd = pd.read_csv('test/logreg/+1e-03_+1e-03/sgd_Hd.csv')
sgd_sgdn = pd.read_csv('test/logreg/+1e-03_+1e-03/sgd_Hdmomentum.csv')
sgd = pd.read_csv('test/logreg/+1e-03_+1e-06/sgd.csv')

sgdn_hd = pd.read_csv('test/logreg/+1e-03_+1e-03/sgdn_Hd.csv')
sgdn_sgdn = pd.read_csv('test/logreg/+1e-03_+1e-03/sgdn_Hdmomentum.csv')
sgdn_adam = pd.read_csv('test/logreg/+1e-03_+1e-03/sgdn_HdAdam.csv')
sgdn = pd.read_csv('test/logreg/+1e-03_+1e-06/sgdn.csv')

adam = pd.read_csv('test/logreg/+1e-03_+1e-06/adam.csv')
adam_hd = pd.read_csv('test/logreg/+1e-03_+1e-07/adam_Hd.csv')
adam_adam = pd.read_csv('test/logreg/+1e-03_+1e-07/adam_HdAdam.csv')
adam_sgdn = pd.read_csv('test/logreg/+1e-03_+1e-07/adam_Hdmomentum.csv')

# %%
sgd_adam.head()
# Out:
#    Epoch  Iteration      Time      Loss  LossEpoch  ValidLossEpoch     Alpha  \
# 0      0          0  0.000000  2.197798   2.197798        2.285788  0.001000
# 1      1          1  0.035285  2.287352        NaN             NaN  0.001000
# 2      1          2  0.062239  2.367012        NaN             NaN  0.001744
# 3      1          3  0.088425  2.204499        NaN             NaN  0.002592
# 4      1          4  0.114034  2.225816        NaN             NaN  0.003492
#
#    AlphaEpoch   Beta
# 0       0.001  0.001
# 1         NaN  0.001
# 2         NaN  0.001
# 3         NaN  0.001
# 4         NaN  0.001

# %%
data = pd.DataFrame()
data['sgd'] = sgd['LossEpoch']
data['sgd_HdAdam'] = sgd_adam['LossEpoch']
data['sgd_Hd'] = sgd_hd['LossEpoch']
data['sgd_Hdmomentum'] = sgd_sgdn['LossEpoch']
data['sgdn_HdAdam'] = sgdn_adam['LossEpoch']
data['sgdn_Hd'] = sgdn_hd['LossEpoch']
data['sgdn_Hdmomentum'] = sgdn_sgdn['LossEpoch']
data['sgdn'] = sgdn['LossEpoch']
data['adam_HdAdam'] = adam_adam['LossEpoch']
data['adam_Hdmomentum'] = adam_sgdn['LossEpoch']
data['adam'] = adam['LossEpoch']
data['adam_Hd'] = adam_hd['LossEpoch']

# %%
data.head()
# Out:
#         sgd  sgd_HdAdam    sgd_Hd  sgd_Hdmomentum  sgdn_HdAdam   sgdn_Hd  \
# 0  2.197798    2.197798  2.197798        2.197798     2.197798  2.197798
# 1       NaN         NaN       NaN             NaN          NaN       NaN
# 2       NaN         NaN       NaN             NaN          NaN       NaN
# 3       NaN         NaN       NaN             NaN          NaN       NaN
# 4       NaN         NaN       NaN             NaN          NaN       NaN
#
#    sgdn_Hdmomentum      sgdn  adam_HdAdam  adam_Hdmomentum      adam   adam_Hd
# 0         2.197798  2.197798     2.197798         2.197798  2.197798  2.197798
# 1              NaN       NaN          NaN              NaN       NaN       NaN
# 2              NaN       NaN          NaN              NaN       NaN       NaN
# 3              NaN       NaN          NaN              NaN       NaN       NaN
# 4              NaN       NaN          NaN              NaN       NaN       NaN

# %%
data_ = data.dropna(axis=0, how='all')

# %%
data_.head()
# Out:
#            sgd  sgd_HdAdam    sgd_Hd  sgd_Hdmomentum  sgdn_HdAdam   sgdn_Hd  \
# 0     2.197798    2.197798  2.197798        2.197798     2.197798  2.197798
# 469   1.204320    0.484514  0.420741        0.442007     0.375690  0.353752
# 938   0.683080    0.325607  0.319863        0.347878     0.290767  0.283570
# 1407  0.564385    0.308802  0.305726        0.330261     0.273284  0.272445
# 1876  0.507047    0.302032  0.299176        0.321634     0.261169  0.268886
#
#       sgdn_Hdmomentum      sgdn  adam_HdAdam  adam_Hdmomentum      adam  \
# 0            2.197798  2.197798     2.197798         2.197798  2.197798
# 469          0.382209  0.567667     0.432330         0.395934  0.432451
# 938          0.294129  0.367116     0.299704         0.294997  0.299748
# 1407         0.282410  0.337566     0.283393         0.281106  0.283449
# 1876         0.273370  0.322315     0.275264         0.273638  0.275441
#
#        adam_Hd
# 0     2.197798
# 469   0.422322
# 938   0.297584
# ...

# %%
len(data_)
# Out:
# 21

# %%
a = list(data.columns)

# %%
a
# Out:
# ['sgd',
#  'sgd_HdAdam',
#  'sgd_Hd',
#  'sgd_Hdmomentum',
#  'sgdn_HdAdam',
#  'sgdn_Hd',
#  'sgdn_Hdmomentum',
#  'sgdn',
#  'adam_HdAdam',
#  'adam_Hdmomentum',
#  'adam',
#  'adam_Hd']

# %%
a
config = {}
config['sgd'] = {'c':'gold', 'linestyle':':'}
config['sgd_HdAdam'] = {'c':'darkred', 'linestyle':':'}
config['sgd_Hd'] = {'c':'black', 'linestyle':':'}
config['sgd_Hdmomentum'] = {'c':'blue', 'linestyle':':'}
config['sgdn_HdAdam'] = {'c':'green', 'linestyle':'--'}
config['sgdn_Hd'] = {'c':'teal', 'linestyle':'--'}
config['sgdn_Hdmomentum'] = {'c':'purple', 'linestyle':'--'}
config['sgdn'] = {'c':'gold', 'linestyle':'--'}
config['adam_HdAdam'] = {'c':'darkturquoise', 'linestyle':'-'}
config['adam_Hdmomentum'] = {'c':'lime','linestyle':'-'}
config['adam'] = {'c':'red', 'linestyle':'-'}
config['adam_Hd'] = {'c':'#721ba6', 'linestyle':'-'} 
data_ = data_.reset_index()

# %%
plt.figure()
for optimizer in a:
    if optimizer in [ 'adam_HdAdam',
 'adam_Hdmomentum',
 'adam',
 'adam_Hd']:
        data_[optimizer].plot(color = config[optimizer]['c'], linestyle = config[optimizer]['linestyle'])
plt.legend(loc = 'best')
plt.xlabel('Epochs')
plt.ylabel('Train Loss')
#plt.ylim(top=0.4, bottom= 0.25)

fig = matplotlib.pyplot.gcf()
fig.set_size_inches(18.5, 10.5)

#plt.show()
plt.savefig('Logreg_Train_Loss_AdamVar.pdf', bbox_inches='tight')

# %%
data_
# Out:
#     index       sgd  sgd_HdAdam    sgd_Hd  sgd_Hdmomentum  sgdn_HdAdam  \
# 0       0  2.197798    2.197798  2.197798        2.197798     2.197798
# 1     469  1.204320    0.484514  0.420741        0.442007     0.375690
# 2     938  0.683080    0.325607  0.319863        0.347878     0.290767
# 3    1407  0.564385    0.308802  0.305726        0.330261     0.273284
# 4    1876  0.507047    0.302032  0.299176        0.321634     0.261169
# 5    2345  0.472099    0.300462  0.296470        0.315459     0.261177
# 6    2814  0.447916    0.299596  0.295031        0.309580     0.264254
# 7    3283  0.430106    0.298990  0.293828        0.304628     0.261327
# 8    3752  0.416252    0.296581  0.293532        0.301044     0.260117
# 9    4221  0.405049    0.297891  0.294063        0.300140     0.260396
# 10   4690  0.395763    0.293622  0.294057        0.296648     0.263150
# 11   5159  0.387867    0.291401  0.293120        0.293113     0.260858
# ...
