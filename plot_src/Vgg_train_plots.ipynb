# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %%
sgd_adam = pd.read_csv('../test/vgg/+1e-03_+1e-03/sgd_HdAdam.csv')
sgd_hd = pd.read_csv('../test/vgg/+1e-03_+1e-03/sgd_Hd.csv')
sgd_sgdn = pd.read_csv('../test/vgg/+1e-03_+1e-03/sgd_Hdmomentum.csv')
sgd = pd.read_csv('../test/vgg/+1e-03_+1e-06/sgd.csv')

sgdn_hd = pd.read_csv('../test/vgg/+1e-03_+1e-03/sgdn_Hd.csv')
sgdn_sgdn = pd.read_csv('../test/vgg/+1e-03_+1e-03/sgdn_Hdmomentum.csv')
#sgdn_adam = pd.read_csv('../test/vgg/+1e-03_+1e-03/sgdn_HdAdam.csv')
sgdn = pd.read_csv('../test/vgg/+1e-03_+1e-06/sgdn.csv')

adam = pd.read_csv('../test/vgg/+1e-03_+1e-06/adam.csv')
adam_hd = pd.read_csv('../test/vgg/+1e-03_+1e-08/adam_Hd.csv')
adam_adam = pd.read_csv('../test/vgg/+1e-03_+1e-08/adam_HdAdam.csv')
#adam_sgdn = pd.read_csv('../test/vgg/+1e-03_+1e-08/adam_Hdmomentum.csv')

# %%
data = pd.DataFrame()
data['sgd_HdAdam'] = sgd_adam['LossEpoch']
data['sgd_Hd'] = sgd_hd['LossEpoch']
data['sgd_Hdmomentum'] = sgd_sgdn['LossEpoch']
data['sgd'] = sgd['LossEpoch']
#data['sgdn_HdAdam'] = sgdn_adam['LossEpoch']
data['sgdn_Hd'] = sgdn_hd['LossEpoch']
data['sgdn_Hdmomentum'] = sgdn_sgdn['LossEpoch']
data['sgdn'] = sgdn['LossEpoch']
data['adam_HdAdam'] = adam_adam['LossEpoch']
#data['adam_Hdmomentum'] = adam_sgdn['LossEpoch']
data['adam'] = adam['LossEpoch']
data['adam_Hd'] = adam_hd['LossEpoch']

# %%
data_ = data.dropna(axis=0, how='all')

# %%
data_.head()
# Out:
#       sgd_HdAdam    sgd_Hd  sgd_Hdmomentum       sgd   sgdn_Hd  \
# 0       2.298176  2.298176        2.298176  2.298176  2.298176
# 391     2.070064  2.182143        1.967776  2.305845  1.787361
# 782     1.798609  1.841785        1.748823  2.296803  1.398332
# 1173    1.741557  1.769055        1.652268  2.284964  1.149929
# 1564    1.697516  1.718458        1.590791  2.262377  1.010083
#
#       sgdn_Hdmomentum      sgdn  adam_HdAdam      adam   adam_Hd
# 0            2.298176  2.298176     2.298176  2.298176  2.298176
# 391          1.720912  2.191352     1.729200  1.731943  1.721506
# 782          1.274874  1.782787     1.359286  1.345271  1.329789
# 1173         1.066770  1.620791     1.099518  1.108184  1.073930
# 1564         0.928992  1.476090     0.918047  0.952347  0.922918

# %%
data_.reset_index(inplace = True)

# %%
data_
# Out:
#      index  sgd_HdAdam    sgd_Hd  sgd_Hdmomentum       sgd   sgdn_Hd  \
# 0        0    2.298176  2.298176        2.298176  2.298176  2.298176
# 1      391    2.070064  2.182143        1.967776  2.305845  1.787361
# 2      782    1.798609  1.841785        1.748823  2.296803  1.398332
# 3     1173    1.741557  1.769055        1.652268  2.284964  1.149929
# 4     1564    1.697516  1.718458        1.590791  2.262377  1.010083
# 5     1955    1.651408  1.667137        1.518435  2.223099  0.895673
# 188         0.040425  0.036247     0.008245  0.113483  0.010501
# 189         0.041872  0.032374     0.008304  0.114588  0.013325
# 190         0.028656  0.029110     0.008510  0.113278  0.013531
# 191         0.020637  0.031253     0.008767  0.115304  0.012215
# 192         0.044154  0.033133     0.009239  0.112044  0.015022
# 193         0.030828  0.032170     0.008883  0.114834  0.010779
# 194         0.025321  0.031977     0.009410  0.115186  0.012280
# 195         0.029668  0.032087     0.009280  0.120369  0.011884
# 196         0.043530  0.031016     0.008253  0.113316  0.012675
# 197         0.023425  0.031849     0.008625  0.111564  0.011416
# 198         0.013269  0.032331     0.009390  0.113064  0.012180
# 199         0.014140  0.030021     0.008059  0.109291  0.013050
# 200         0.010702  0.030351     0.008086  0.109994  0.014574
#
# [201 rows x 11 columns]

# %%
config = {}
config['sgd_HdAdam'] = {'c':'#1109ed', 'linestyle':'-.'}#03d1ff
config['sgd_Hd'] = {'c':'#1109ed', 'linestyle':'--', 'l':'op_sgd_lop_sgd (SGD-HD)'}
config['sgd_Hdmomentum'] = {'c':'#1109ed', 'linestyle':'-', 'l':'op_sgd_lop_sgdn'}#11f505
config['sgd'] = {'c':'#d5a767', 'linestyle':'-'}
#config['sgdn_HdAdam'] = {'c':'green', 'linestyle':'-'}
config['sgdn_Hd'] = {'c':'#fa0207', 'linestyle':'--', 'l':'op_sgdn_lop_sgd (SGDN-HD)'}
config['sgdn_Hdmomentum'] = {'c':'#fa0207', 'linestyle':'-', 'l':'op_sgdn_lop_sgdn'}#f705b2
config['sgdn'] = {'c':'#0339ff', 'linestyle':'-'}
config['adam_HdAdam'] = {'c':'#257002', 'linestyle':'-', 'l':'op_adam_lop_adam'}#0df705
#config['adam_Hdmomentum'] = {'c':'lime','linestyle':'--'}
config['adam'] = {'c':'#fa4c05', 'linestyle':'-'}
config['adam_Hd'] = {'c':'#257002', 'linestyle':'--', 'l':'op_adam_lop_sgd (Adam-HD)'}##11f505

# %%
a = list(data.columns)
a = [ 'sgd_Hd','sgd_Hdmomentum','sgd_HdAdam', 'sgdn_Hd', 'sgdn_Hdmomentum','adam_Hd','adam_HdAdam']

# %%
plt.figure()
SMALL_SIZE= 18
MED_SIZE= 22
BIG_SIZE = 32
plt.rc('legend', fontsize=MED_SIZE)    # legend fontsize
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE) 
plt.rc('axes', labelsize=BIG_SIZE)    # fontsize of the x and y labels
param = {'size':'42'}
for optimizer in a:
    if optimizer not in ['adam', 'sgd', 'sgdn', 'sgd_HdAdam']:
        data_[optimizer].plot(color = config[optimizer]['c'], linestyle = config[optimizer]['linestyle'], label=config[optimizer]['l'])
plt.legend(loc = 'best')
#plt.xlabel('Epochs')
plt.ylabel('Training Loss')
plt.ylim(bottom= -0.25)
plt.grid(True)

fig = matplotlib.pyplot.gcf()
fig.set_size_inches(18.5, 10.5)
#plt.axhline(y=0.2, color='r', linestyle='-')

#plt.show()
plt.savefig('Vgg_train_Loss.pdf', bbox_inches='tight')

# %%
a
# Out:
# ['sgd_Hd',
#  'sgd_Hdmomentum',
#  'sgd_HdAdam',
#  'sgdn_Hd',
#  'sgdn_Hdmomentum',
#  'adam_Hd',
#  'adam_HdAdam']
