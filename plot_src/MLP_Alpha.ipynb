# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %%
sgd_adam = pd.read_csv('../test/mlp/+1e-03_+1e-03/sgd_HdAdam.csv')
sgd_hd = pd.read_csv('../test/mlp/+1e-03_+1e-03/sgd_Hd.csv')
sgd_sgdn = pd.read_csv('../test/mlp/+1e-03_+1e-03/sgd_Hdmomentum.csv')
sgd = pd.read_csv('../test/mlp/+1e-03_+1e-06/sgd.csv')

sgdn_hd = pd.read_csv('../test/mlp/+1e-03_+1e-03/sgdn_Hd.csv')
sgdn_sgdn = pd.read_csv('../test/mlp/+1e-03_+1e-03/sgdn_Hdmomentum.csv')
sgdn_adam = pd.read_csv('../test/mlp/+1e-03_+1e-03/sgdn_HdAdam.csv')
sgdn = pd.read_csv('../test/mlp/+1e-03_+1e-06/sgdn.csv')

adam = pd.read_csv('../test/mlp/+1e-03_+1e-06/adam.csv')
adam_hd = pd.read_csv('../test/mlp/+1e-03_+1e-07/adam_Hd.csv')
adam_adam = pd.read_csv('../test/mlp/+1e-03_+1e-07/adam_HdAdam.csv')
adam_sgdn = pd.read_csv('../test/mlp/+1e-03_+1e-07/adam_Hdmomentum.csv')

# %%
sgd_adam.head()
# Out:
#    Epoch  Iteration      Time      Loss  LossEpoch  ValidLossEpoch     Alpha  \
# 0      0          0  0.000000  2.295416   2.295416        2.299237  0.001000
# 1      1          1  0.015787  2.298943        NaN             NaN  0.001000
# 2      1          2  0.034179  2.298906        NaN             NaN  0.001744
# 3      1          3  0.048116  2.292472        NaN             NaN  0.002598
# 4      1          4  0.061748  2.308896        NaN             NaN  0.003506
#
#    AlphaEpoch   Beta
# 0       0.001  0.001
# 1         NaN  0.001
# 2         NaN  0.001
# 3         NaN  0.001
# 4         NaN  0.001

# %%
data = pd.DataFrame()
data['sgd_HdAdam'] = sgd_adam['AlphaEpoch']
data['sgd_Hd'] = sgd_hd['AlphaEpoch']
data['sgd_Hdmomentum'] = sgd_sgdn['AlphaEpoch']
data['sgd'] = sgd['AlphaEpoch']
#data['sgdn_HdAdam'] = sgdn_adam['AlphaEpoch']
data['sgdn_Hd'] = sgdn_hd['AlphaEpoch']
data['sgdn_Hdmomentum'] = sgdn_sgdn['AlphaEpoch']
data['sgdn'] = sgdn['AlphaEpoch']
data['adam_HdAdam'] = adam_adam['AlphaEpoch']
#data['adam_Hdmomentum'] = adam_sgdn['AlphaEpoch']
data['adam'] = adam['AlphaEpoch']
data['adam_Hd'] = adam_hd['AlphaEpoch']

# %%
data.head()
# Out:
#    sgd_HdAdam  sgd_Hd  sgd_Hdmomentum    sgd  sgdn_Hd  sgdn_Hdmomentum   sgdn  \
# 0       0.001   0.001           0.001  0.001    0.001            0.001  0.001
# 1         NaN     NaN             NaN    NaN      NaN              NaN    NaN
# 2         NaN     NaN             NaN    NaN      NaN              NaN    NaN
# 3         NaN     NaN             NaN    NaN      NaN              NaN    NaN
# 4         NaN     NaN             NaN    NaN      NaN              NaN    NaN
#
#    adam_HdAdam   adam  adam_Hd
# 0        0.001  0.001    0.001
# 1          NaN    NaN      NaN
# 2          NaN    NaN      NaN
# 3          NaN    NaN      NaN
# 4          NaN    NaN      NaN

# %%
data_ = data.dropna(axis=0, how='all')

# %%
data_.head()
# Out:
#       sgd_HdAdam    sgd_Hd  sgd_Hdmomentum    sgd   sgdn_Hd  sgdn_Hdmomentum  \
# 0       0.001000  0.001000        0.001000  0.001  0.001000         0.001000
# 469     0.014965  0.016170        0.015034  0.001  0.005697         0.010970
# 938     0.003030  0.002281        0.006457  0.001  0.002334         0.005204
# 1407    0.003964  0.003123        0.008608  0.001  0.003851         0.006738
# 1876    0.002455  0.001385        0.006066  0.001  0.002816         0.006086
#
#        sgdn  adam_HdAdam   adam   adam_Hd
# 0     0.001     0.001000  0.001  0.001000
# 469   0.001     0.000982  0.001  0.000843
# 938   0.001     0.000952  0.001  0.000707
# 1407  0.001     0.000924  0.001  0.000631
# 1876  0.001     0.000899  0.001  0.000581

# %%
data_.reset_index(inplace = True)

# %%
len(data_)
# Out:
# 101

# %%
a = list(data.columns)

# %%
a = a = [ 'sgd_Hd','sgd_Hdmomentum','sgd_HdAdam', 'sgdn_Hd', 'sgdn_Hdmomentum','adam_Hd','adam_HdAdam']

# %%
config = {}
config['sgd_HdAdam'] = {'c':'#1109ed', 'linestyle':'-.'}#03d1ff
config['sgd_Hd'] = {'c':'#1109ed', 'linestyle':'--', 'l':'op_sgd_lop_sgd (SGD-HD)'}
config['sgd_Hdmomentum'] = {'c':'#1109ed', 'linestyle':'-', 'l':'op_sgd_lop_sgdn'}#11f505
config['sgd'] = {'c':'#d5a767', 'linestyle':'-'}
#config['sgdn_HdAdam'] = {'c':'green', 'linestyle':'-'}
config['sgdn_Hd'] = {'c':'#fa0207', 'linestyle':'--', 'l':'op_sgdn_lop_sgd (SGDN-HD)'}
config['sgdn_Hdmomentum'] = {'c':'#fa0207', 'linestyle':'-', 'l':'op_sgdn_lop_sgdn'}#f705b2
config['sgdn'] = {'c':'#0339ff', 'linestyle':'-'}
config['adam_HdAdam'] = {'c':'#257002', 'linestyle':'-', 'l':'op_adam_lop_adam'}#0df705
#config['adam_Hdmomentum'] = {'c':'lime','linestyle':'--'}
config['adam'] = {'c':'#fa4c05', 'linestyle':'-'}
config['adam_Hd'] = {'c':'#257002', 'linestyle':'--', 'l':'op_adam_lop_sgd (Adam-HD)'}##11f505

# %%
plt.figure()
SMALL_SIZE= 18
MED_SIZE= 22
BIG_SIZE = 32
plt.rc('legend', fontsize=MED_SIZE)    # legend fontsize
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE) 
plt.rc('axes', labelsize=BIG_SIZE)    # fontsize of the x and y labels
param = {'size':'42'}
for optimizer in a:
    if optimizer not in ['adam', 'sgd', 'sgdn', 'sgd_HdAdam']:
        data_[optimizer].plot(color = config[optimizer]['c'], linestyle = config[optimizer]['linestyle'], label=config[optimizer]['l'])
plt.legend(loc = 'best')
#plt.xlabel('Epochs')
plt.ylabel('Alpha')
plt.ylim(bottom= -0.001)
plt.grid(True)

fig = matplotlib.pyplot.gcf()
fig.set_size_inches(18.5, 10.5)
#plt.axhline(y=0.2, color='r', linestyle='-')

#plt.show()
plt.savefig('MLP_Alpha.pdf', bbox_inches='tight')

# %%
data_
# Out:
#      index  sgd_HdAdam    sgd_Hd  sgd_Hdmomentum    sgd   sgdn_Hd  \
# 0        0    0.001000  0.001000        0.001000  0.001  0.001000
# 1      469    0.014965  0.016170        0.015034  0.001  0.005697
# 2      938    0.003030  0.002281        0.006457  0.001  0.002334
# 3     1407    0.003964  0.003123        0.008608  0.001  0.003851
# 4     1876    0.002455  0.001385        0.006066  0.001  0.002816
# 5     2345    0.002342  0.002225        0.004771  0.001  0.002638
# 6     2814    0.003319  0.001295        0.005750  0.001  0.002584
# 7     3283    0.002532  0.000886        0.004683  0.001  0.001200
# 8     3752    0.003235  0.002285        0.006471  0.001  0.002940
# 9     4221    0.002674  0.001222        0.005907  0.001  0.002069
# 10    4690    0.002997  0.001963        0.005444  0.001  0.001687
# 11    5159    0.005298  0.002326        0.004904  0.001  0.001057
# 12    5628    0.002135  0.000747        0.003136  0.001  0.001537
# 13    6097    0.003987  0.001996        0.007548  0.001  0.001811
# 14    6566    0.003841  0.002464        0.007477  0.001  0.002316
# 15    7035    0.003670  0.001057        0.010236  0.001  0.000917
# 16    7504    0.004035  0.001654        0.003311  0.001  0.000893
# 17    7973    0.002918  0.001220        0.004828  0.001  0.001486
# 18    8442    0.003805  0.001126        0.007274  0.001  0.001766
# 19    8911    0.004291  0.002491        0.006408  0.001  0.001837
# 20    9380    0.005112  0.003219        0.007252  0.001  0.001365
# 21    9849    0.003683  0.000537        0.002668  0.001  0.000823
# 22   10318    0.005058  0.002524        0.006591  0.001  0.000730
# 23   10787    0.008555  0.003867        0.006958  0.001  0.000723
# 24   11256    0.003339  0.003749        0.006484  0.001  0.000779
# 25   11725    0.006070  0.002023        0.008302  0.001  0.001030
# 26   12194    0.003690  0.000914        0.003475  0.001  0.001370
# 27   12663    0.006082  0.001964        0.006516  0.001  0.001182
# 28   13132    0.003853  0.001419        0.004871  0.001  0.000822
# 29   13601    0.002516  0.000126        0.003172  0.001  0.000794
# ..     ...         ...       ...             ...    ...       ...
# 71   33299    0.009151  0.000809        0.008037  0.001  0.000363
# 72   33768    0.005518  0.000421        0.003244  0.001  0.000125
# 73   34237    0.005907  0.001724        0.006342  0.001  0.000285
# 74   34706    0.002917  0.002855        0.002192  0.001  0.000193
# 75   35175    0.005478  0.001870        0.004617  0.001  0.000173
# 76   35644    0.004136  0.000815        0.003307  0.001  0.000150
# 77   36113    0.002978  0.003190        0.002695  0.001  0.000128
# 78   36582    0.005878  0.002481        0.006286  0.001  0.000627
# 79   37051    0.003034  0.000294        0.004222  0.001  0.000149
# 80   37520    0.005632  0.001731        0.007210  0.001  0.001849
# 81   37989    0.007001  0.002305        0.003734  0.001  0.002242
# 82   38458    0.003421  0.000592        0.001315  0.001  0.002664
# 83   38927    0.005620  0.000417        0.003941  0.001  0.002966
# 84   39396    0.004966  0.001605        0.002607  0.001  0.002184
# 85   39865    0.012090  0.000513        0.008489  0.001  0.002099
# 86   40334    0.004744  0.000468        0.003107  0.001  0.001742
# 87   40803    0.003108  0.002202        0.002719  0.001  0.001060
# 88   41272    0.003287  0.001481        0.001819  0.001  0.000603
# 89   41741    0.007232  0.003429        0.005193  0.001  0.000341
# 90   42210    0.005138  0.003822        0.004800  0.001  0.000858
# 91   42679    0.006746  0.002489        0.002315  0.001  0.000744
# 92   43148    0.003069  0.000863        0.001417  0.001  0.000255
# 93   43617    0.001836  0.000918        0.001022  0.001  0.000285
# 94   44086    0.005031  0.001315        0.002522  0.001  0.000184
# 95   44555    0.005837  0.000160        0.002355  0.001  0.000093
# 96   45024    0.007059  0.002535        0.007854  0.001  0.000507
# 97   45493    0.010204  0.000439        0.005994  0.001  0.000321
# 98   45962    0.004851  0.001350        0.006343  0.001  0.001206
# 99   46431    0.004489  0.000432        0.001722  0.001  0.000653
# 100  46900    0.005267  0.000555        0.002832  0.001  0.000155
#
#      sgdn_Hdmomentum   sgdn  adam_HdAdam   adam       adam_Hd
# 0           0.001000  0.001     0.001000  0.001  1.000000e-03
# 1           0.010970  0.001     0.000982  0.001  8.434941e-04
# 2           0.005204  0.001     0.000952  0.001  7.074618e-04
# 3           0.006738  0.001     0.000924  0.001  6.309488e-04
# 4           0.006086  0.001     0.000899  0.001  5.806149e-04
# 5           0.004553  0.001     0.000872  0.001  5.351268e-04
# 6           0.005380  0.001     0.000846  0.001  4.950666e-04
# 7           0.004952  0.001     0.000823  0.001  4.577453e-04
# 8           0.005230  0.001     0.000803  0.001  4.299880e-04
# 9           0.006290  0.001     0.000776  0.001  4.055766e-04
# 10          0.005591  0.001     0.000740  0.001  3.784220e-04
# 11          0.003569  0.001     0.000716  0.001  3.659788e-04
# 12          0.004342  0.001     0.000688  0.001  3.440725e-04
# 13          0.004545  0.001     0.000669  0.001  3.256441e-04
# 14          0.002654  0.001     0.000658  0.001  3.168830e-04
# 15          0.001687  0.001     0.000637  0.001  2.939988e-04
# 16          0.004430  0.001     0.000612  0.001  2.711152e-04
# 17          0.004581  0.001     0.000590  0.001  2.607004e-04
# 18          0.005201  0.001     0.000559  0.001  2.465192e-04
# 19          0.004515  0.001     0.000534  0.001  2.340630e-04
# 20          0.002906  0.001     0.000504  0.001  2.170075e-04
# 21          0.001803  0.001     0.000486  0.001  2.080832e-04
# 22          0.001181  0.001     0.000449  0.001  2.073346e-04
# 23          0.001771  0.001     0.000424  0.001  2.012830e-04
# 24          0.002258  0.001     0.000414  0.001  1.691292e-04
# 25          0.002642  0.001     0.000409  0.001  1.496302e-04
# 26          0.002446  0.001     0.000376  0.001  1.479897e-04
# 27          0.001663  0.001     0.000338  0.001  1.472412e-04
# 28          0.000360  0.001     0.000327  0.001  1.434532e-04
# 29          0.000776  0.001     0.000306  0.001  1.133567e-04
# ..               ...    ...          ...    ...           ...
# 71          0.001776  0.001     0.000011  0.001  1.167088e-05
# 72          0.000334  0.001     0.000005  0.001  9.895211e-06
# 73          0.000026  0.001     0.000007  0.001  9.086675e-06
# 74          0.000235  0.001     0.000004  0.001  8.237292e-06
# 75          0.000613  0.001     0.000003  0.001  7.449002e-06
# 76          0.000369  0.001     0.000002  0.001  6.005947e-06
# 77          0.000054  0.001     0.000010  0.001  4.672674e-06
# 78         -0.000006  0.001     0.000012  0.001  4.138990e-06
# 79          0.000187  0.001     0.000002  0.001  2.037550e-06
# 80          0.001025  0.001     0.000010  0.001  1.658717e-06
# 81          0.001532  0.001     0.000004  0.001  5.613440e-07
# 82          0.002782  0.001     0.000012  0.001  5.568140e-07
# 83          0.004505  0.001     0.000024  0.001  8.696140e-07
# 84          0.003311  0.001     0.000018  0.001 -1.056148e-07
# 85          0.003015  0.001     0.000022  0.001  3.117662e-07
# 86          0.002264  0.001     0.000011  0.001 -1.836609e-08
# 87          0.001733  0.001     0.000005  0.001  7.691288e-07
# 88          0.001450  0.001     0.000001  0.001 -2.436235e-08
# 89          0.000967  0.001     0.000007  0.001  9.568677e-07
# 90          0.001349  0.001     0.000012  0.001  9.664837e-07
# 91          0.001237  0.001     0.000008  0.001 -7.421543e-08
# 92          0.000455  0.001     0.000004  0.001  4.351819e-07
# 93          0.000913  0.001     0.000007  0.001  1.685999e-06
# 94          0.001023  0.001     0.000003  0.001  9.953532e-07
# 95          0.000268  0.001     0.000004  0.001 -3.095197e-07
# 96          0.000494  0.001     0.000009  0.001  1.230628e-06
# 97          0.000376  0.001     0.000014  0.001  9.379455e-07
# 98          0.001095  0.001     0.000016  0.001  3.495102e-07
# 99          0.000654  0.001     0.000012  0.001 -2.285369e-07
# 100        -0.000211  0.001     0.000012  0.001  1.294514e-06
#
# [101 rows x 11 columns]
