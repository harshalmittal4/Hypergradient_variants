# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %%
sgd_adam = pd.read_csv('../test/vgg/+1e-03_+1e-03/sgd_HdAdam.csv')
sgd_hd = pd.read_csv('../test/vgg/+1e-03_+1e-03/sgd_Hd.csv')
sgd_sgdn = pd.read_csv('../test/vgg/+1e-03_+1e-03/sgd_Hdmomentum.csv')
sgd = pd.read_csv('../test/vgg/+1e-03_+1e-06/sgd.csv')

sgdn_hd = pd.read_csv('../test/vgg/+1e-03_+1e-03/sgdn_Hd.csv')
sgdn_sgdn = pd.read_csv('../test/vgg/+1e-03_+1e-03/sgdn_Hdmomentum.csv')
#sgdn_adam = pd.read_csv('../test/vgg/+1e-03_+1e-03/sgdn_HdAdam.csv')
sgdn = pd.read_csv('../test/vgg/+1e-03_+1e-06/sgdn.csv')

adam = pd.read_csv('../test/vgg/+1e-03_+1e-06/adam.csv')
adam_hd = pd.read_csv('../test/vgg/+1e-03_+1e-08/adam_Hd.csv')
adam_adam = pd.read_csv('../test/vgg/+1e-03_+1e-08/adam_HdAdam.csv')
#adam_sgdn = pd.read_csv('../test/vgg/+1e-03_+1e-08/adam_Hdmomentum.csv')

# %%
data = pd.DataFrame()
data['sgd_HdAdam'] = sgd_adam['ValidLossEpoch']
data['sgd_Hd'] = sgd_hd['ValidLossEpoch']
data['sgd_Hdmomentum'] = sgd_sgdn['ValidLossEpoch']
data['sgd'] = sgd['ValidLossEpoch']
#data['sgdn_HdAdam'] = sgdn_adam['ValidLossEpoch']
data['sgdn_Hd'] = sgdn_hd['ValidLossEpoch']
data['sgdn_Hdmomentum'] = sgdn_sgdn['ValidLossEpoch']
data['sgdn'] = sgdn['ValidLossEpoch']
data['adam_HdAdam'] = adam_adam['ValidLossEpoch']
#data['adam_Hdmomentum'] = adam_sgdn['ValidLossEpoch']
data['adam'] = adam['ValidLossEpoch']
data['adam_Hd'] = adam_hd['ValidLossEpoch']

# %%
data_ = data.dropna(axis=0, how='all')

# %%
data_.head()
# Out:
#       sgd_HdAdam    sgd_Hd  sgd_Hdmomentum       sgd   sgdn_Hd  \
# 0       2.302998  2.302998        2.302998  2.302998  2.302998
# 391     1.804394  1.829373        1.776247  2.296039  1.486405
# 782     1.710497  1.765957        1.639567  2.287166  1.454698
# 1173    1.650153  1.721478        1.585458  2.269959  1.548394
# 1564    1.756874  1.717490        1.510226  2.233999  0.915642
#
#       sgdn_Hdmomentum      sgdn  adam_HdAdam      adam   adam_Hd
# 0            2.302998  2.302998     2.302998  2.302998  2.302998
# 391          1.341687  1.888291     1.791538  1.535061  1.605668
# 782          1.111503  1.643690     1.277227  1.478133  1.472914
# 1173         0.988909  1.473595     1.032093  1.110452  1.101937
# 1564         0.852255  1.381297     0.890243  0.884405  0.868310

# %%
data_.reset_index(inplace = True)

# %%
data_
# Out:
#      index  sgd_HdAdam    sgd_Hd  sgd_Hdmomentum       sgd   sgdn_Hd  \
# 0        0    2.302998  2.302998        2.302998  2.302998  2.302998
# 1      391    1.804394  1.829373        1.776247  2.296039  1.486405
# 2      782    1.710497  1.765957        1.639567  2.287166  1.454698
# 3     1173    1.650153  1.721478        1.585458  2.269959  1.548394
# 4     1564    1.756874  1.717490        1.510226  2.233999  0.915642
# 5     1955    1.545838  1.584184        1.417000  2.174511  0.881061
# 191         0.410170  0.620856     0.534325  0.353592  0.473013
# 192         0.429346  0.629706     0.535911  0.373344  0.454198
# 193         0.396174  0.609284     0.534766  0.376469  0.493966
# 194         0.404075  0.651932     0.555040  0.418846  0.473859
# 195         0.460436  0.644623     0.544190  0.379829  0.494347
# 196         0.414520  0.631070     0.545773  0.390621  0.475671
# 197         0.381298  0.641306     0.541188  0.344231  0.493281
# 198         0.415589  0.629623     0.537343  0.358802  0.524589
# 199         0.426199  0.629332     0.532676  0.395760  0.497565
# 200         0.440501  0.618486     0.542439  0.399594  0.483883
#
# [201 rows x 11 columns]

# %%
config = {}
config['sgd_HdAdam'] = {'c':'#1109ed', 'linestyle':'-.'}#03d1ff
config['sgd_Hd'] = {'c':'#1109ed', 'linestyle':'--', 'l':'op_sgd_lop_sgd (SGD-HD)'}
config['sgd_Hdmomentum'] = {'c':'#1109ed', 'linestyle':'-', 'l':'op_sgd_lop_sgdn'}#11f505
config['sgd'] = {'c':'#d5a767', 'linestyle':'-'}
#config['sgdn_HdAdam'] = {'c':'green', 'linestyle':'-'}
config['sgdn_Hd'] = {'c':'#fa0207', 'linestyle':'--', 'l':'op_sgdn_lop_sgd (SGDN-HD)'}
config['sgdn_Hdmomentum'] = {'c':'#fa0207', 'linestyle':'-', 'l':'op_sgdn_lop_sgdn'}#f705b2
config['sgdn'] = {'c':'#0339ff', 'linestyle':'-'}
config['adam_HdAdam'] = {'c':'#257002', 'linestyle':'-', 'l':'op_adam_lop_adam'}#0df705
#config['adam_Hdmomentum'] = {'c':'lime','linestyle':'--'}
config['adam'] = {'c':'#fa4c05', 'linestyle':'-'}
config['adam_Hd'] = {'c':'#257002', 'linestyle':'--', 'l':'op_adam_lop_sgd (Adam-HD)'}##11f505

# %%
a = list(data.columns)
a = [ 'sgd_Hd','sgd_Hdmomentum','sgd_HdAdam', 'sgdn_Hd', 'sgdn_Hdmomentum','adam_Hd','adam_HdAdam']

# %%
plt.figure()
SMALL_SIZE= 18
MED_SIZE= 22
BIG_SIZE = 32
plt.rc('legend', fontsize=MED_SIZE)    # legend fontsize
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE) 
plt.rc('axes', labelsize=BIG_SIZE)    # fontsize of the x and y labels
param = {'size':'42'}
for optimizer in a:
    if optimizer not in ['adam', 'sgd', 'sgdn', 'sgd_HdAdam']:
        data_[optimizer].plot(color = config[optimizer]['c'], linestyle = config[optimizer]['linestyle'], label=config[optimizer]['l'])
    #if (optimizer in ['adam_HdAdam',
 #'adam_Hdmomentum',
 #'adam',
 #'adam_Hd' ]):
  #      data_[optimizer].plot(color = config[optimizer]['c'], l = config[optimizer]['linestyle'])

plt.legend(loc = 'best')
plt.xlabel('Epochs', **param)
plt.ylabel('Validation Loss')
plt.ylim(top = 2.25)
plt.grid(True)

fig = matplotlib.pyplot.gcf()
fig.set_size_inches(18.5, 10.5)

#plt.show()
plt.savefig('Vgg_valid_Loss.pdf', bbox_inches='tight')

# %%
a
# Out:
# ['sgd_Hd',
#  'sgd_Hdmomentum',
#  'sgd_HdAdam',
#  'sgdn_Hd',
#  'sgdn_Hdmomentum',
#  'adam_Hd',
#  'adam_HdAdam']
