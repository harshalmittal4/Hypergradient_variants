# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %%
sgd_adam = pd.read_csv('../test/logreg/+1e-03_+1e-03/sgd_HdAdam.csv')
sgd_hd = pd.read_csv('../test/logreg/+1e-03_+1e-03/sgd_Hd.csv')
sgd_sgdn = pd.read_csv('../test/logreg/+1e-03_+1e-03/sgd_Hdmomentum.csv')
sgd = pd.read_csv('../test/logreg/+1e-03_+1e-06/sgd.csv')

sgdn_hd = pd.read_csv('../test/logreg/+1e-03_+1e-03/sgdn_Hd.csv')
sgdn_sgdn = pd.read_csv('../test/logreg/+1e-03_+1e-03/sgdn_Hdmomentum.csv')
sgdn_adam = pd.read_csv('../test/logreg/+1e-03_+1e-03/sgdn_HdAdam.csv')
sgdn = pd.read_csv('../test/logreg/+1e-03_+1e-06/sgdn.csv')

adam = pd.read_csv('../test/logreg/+1e-03_+1e-06/adam.csv')
adam_hd = pd.read_csv('../test/logreg/+1e-03_+1e-07/adam_Hd.csv')
adam_adam = pd.read_csv('../test/logreg/+1e-03_+1e-07/adam_HdAdam.csv')
adam_sgdn = pd.read_csv('../test/logreg/+1e-03_+1e-07/adam_Hdmomentum.csv')

# %%
sgd_adam.head()
# Out:
#    Epoch  Iteration      Time      Loss  LossEpoch  ValidLossEpoch     Alpha  \
# 0      0          0  0.000000  2.197798   2.197798        2.285788  0.001000
# 1      1          1  0.035285  2.287352        NaN             NaN  0.001000
# 2      1          2  0.062239  2.367012        NaN             NaN  0.001744
# 3      1          3  0.088425  2.204499        NaN             NaN  0.002592
# 4      1          4  0.114034  2.225816        NaN             NaN  0.003492
#
#    AlphaEpoch   Beta
# 0       0.001  0.001
# 1         NaN  0.001
# 2         NaN  0.001
# 3         NaN  0.001
# 4         NaN  0.001

# %%
data = pd.DataFrame()
data['sgd_HdAdam'] = sgd_adam['ValidLossEpoch']
data['sgd_Hd'] = sgd_hd['ValidLossEpoch']
data['sgd_Hdmomentum'] = sgd_sgdn['ValidLossEpoch']
data['sgd'] = sgd['ValidLossEpoch']
#data['sgdn_HdAdam'] = sgdn_adam['ValidLossEpoch']
data['sgdn_Hd'] = sgdn_hd['ValidLossEpoch']
data['sgdn_Hdmomentum'] = sgdn_sgdn['ValidLossEpoch']
data['sgdn'] = sgdn['ValidLossEpoch']
data['adam_HdAdam'] = adam_adam['ValidLossEpoch']
#data['adam_Hdmomentum'] = adam_sgdn['ValidLossEpoch']
data['adam'] = adam['ValidLossEpoch']
data['adam_Hd'] = adam_hd['ValidLossEpoch']

# %%
data.head()
# Out:
#    sgd_HdAdam    sgd_Hd  sgd_Hdmomentum       sgd   sgdn_Hd  sgdn_Hdmomentum  \
# 0    2.285788  2.285788        2.285788  2.285788  2.285788         2.285788
# 1         NaN       NaN             NaN       NaN       NaN              NaN
# 2         NaN       NaN             NaN       NaN       NaN              NaN
# 3         NaN       NaN             NaN       NaN       NaN              NaN
# 4         NaN       NaN             NaN       NaN       NaN              NaN
#
#        sgdn  adam_HdAdam      adam   adam_Hd
# 0  2.285788     2.285788  2.285788  2.285788
# 1       NaN          NaN       NaN       NaN
# 2       NaN          NaN       NaN       NaN
# 3       NaN          NaN       NaN       NaN
# 4       NaN          NaN       NaN       NaN

# %%
data_ = data.dropna(axis=0, how='all')

# %%
data_.head()
# Out:
#       sgd_HdAdam    sgd_Hd  sgd_Hdmomentum       sgd   sgdn_Hd  \
# 0       2.285788  2.285788        2.285788  2.285788  2.285788
# 469     0.323989  0.316285        0.342034  0.769226  0.286201
# 938     0.302498  0.299395        0.319564  0.583714  0.277509
# 1407    0.295410  0.293206        0.312912  0.508202  0.273482
# 1876    0.293649  0.290807        0.305531  0.465842  0.273307
#
#       sgdn_Hdmomentum      sgdn  adam_HdAdam      adam   adam_Hd
# 0            2.285788  2.285788     2.285788  2.285788  2.285788
# 469          0.293920  0.373228     0.298360  0.298398  0.295049
# 938          0.281055  0.333106     0.282138  0.282190  0.281787
# 1407         0.279088  0.314978     0.275881  0.275890  0.275339
# 1876         0.277808  0.304999     0.279054  0.279605  0.281556

# %%
data_.reset_index(inplace = True)

# %%
len(data_)
# Out:
# 21

# %%
a = list(data.columns)
a = [ 'sgd_Hd','sgd_Hdmomentum','sgd_HdAdam', 'sgdn_Hd', 'sgdn_Hdmomentum','adam_Hd','adam_HdAdam']

# %%
a
# Out:
# ['sgd_Hd',
#  'sgd_Hdmomentum',
#  'sgd_HdAdam',
#  'sgdn_Hd',
#  'sgdn_Hdmomentum',
#  'adam_Hd',
#  'adam_HdAdam']

# %%
config = {}
config['sgd_HdAdam'] = {'c':'#1109ed', 'linestyle':'-.'}#03d1ff
config['sgd_Hd'] = {'c':'#1109ed', 'linestyle':'--', 'l':'op_sgd_lop_sgd (SGD-HD)'}
config['sgd_Hdmomentum'] = {'c':'#1109ed', 'linestyle':'-', 'l':'op_sgd_lop_sgdn'}#11f505
config['sgd'] = {'c':'#d5a767', 'linestyle':'-'}
#config['sgdn_HdAdam'] = {'c':'green', 'linestyle':'-'}
config['sgdn_Hd'] = {'c':'#fa0207', 'linestyle':'--', 'l':'op_sgdn_lop_sgd (SGDN-HD)'}
config['sgdn_Hdmomentum'] = {'c':'#fa0207', 'linestyle':'-', 'l':'op_sgdn_lop_sgdn'}#f705b2
config['sgdn'] = {'c':'#0339ff', 'linestyle':'-'}
config['adam_HdAdam'] = {'c':'#257002', 'linestyle':'-', 'l':'op_adam_lop_adam'}#0df705
#config['adam_Hdmomentum'] = {'c':'lime','linestyle':'--'}
config['adam'] = {'c':'#fa4c05', 'linestyle':'-'}
config['adam_Hd'] = {'c':'#257002', 'linestyle':'--', 'l':'op_adam_lop_sgd (Adam-HD)'}##11f505

# %%
plt.figure()
SMALL_SIZE= 18
MED_SIZE= 22
BIG_SIZE = 32
plt.rc('legend', fontsize=MED_SIZE)    # legend fontsize
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE) 
plt.rc('axes', labelsize=BIG_SIZE)    # fontsize of the x and y labels
param = {'size':'42'}
for optimizer in a:
    if optimizer not in ['adam', 'sgd', 'sgdn', 'sgd_HdAdam']:
        data_[optimizer].plot(color = config[optimizer]['c'], linestyle = config[optimizer]['linestyle'], label=config[optimizer]['l'])
    #if (optimizer in ['adam_HdAdam',
 #'adam_Hdmomentum',
 #'adam',
 #'adam_Hd' ]):
  #      data_[optimizer].plot(color = config[optimizer]['c'], l = config[optimizer]['linestyle'])

plt.legend(loc = 'best')
plt.xlabel('Epochs', **param)
plt.ylabel('Validation Loss')
plt.ylim(bottom= 0.25, top = 0.40)
plt.grid(True)

fig = matplotlib.pyplot.gcf()
fig.set_size_inches(18.5, 10.5)

#plt.show()
plt.savefig('LogReg_valid_Loss.pdf', bbox_inches='tight')

# %%
data_
# Out:
#     index  sgd_HdAdam    sgd_Hd  sgd_Hdmomentum       sgd   sgdn_Hd  \
# 0       0    2.285788  2.285788        2.285788  2.285788  2.285788
# 1     469    0.323989  0.316285        0.342034  0.769226  0.286201
# 2     938    0.302498  0.299395        0.319564  0.583714  0.277509
# 3    1407    0.295410  0.293206        0.312912  0.508202  0.273482
# 4    1876    0.293649  0.290807        0.305531  0.465842  0.273307
# 5    2345    0.293635  0.289849        0.301849  0.437935  0.274760
# 6    2814    0.291833  0.288879        0.296976  0.418194  0.273221
# 7    3283    0.290748  0.289154        0.293513  0.403196  0.273300
# 8    3752    0.290171  0.289084        0.292789  0.391477  0.271361
# 9    4221    0.289460  0.289240        0.290306  0.381744  0.273099
# 10   4690    0.288657  0.289547        0.289267  0.374066  0.273508
# 11   5159    0.286342  0.288314        0.286549  0.367017  0.271436
# 12   5628    0.284877  0.288160        0.285488  0.360977  0.270840
# ...
