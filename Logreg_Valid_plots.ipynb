# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

# %%
sgd_adam = pd.read_csv('test/logreg/+1e-03_+1e-03/sgd_HdAdam.csv')
sgd_hd = pd.read_csv('test/logreg/+1e-03_+1e-03/sgd_Hd.csv')
sgd_sgdn = pd.read_csv('test/logreg/+1e-03_+1e-03/sgd_Hdmomentum.csv')
sgd = pd.read_csv('test/logreg/+1e-03_+1e-06/sgd.csv')

sgdn_hd = pd.read_csv('test/logreg/+1e-03_+1e-03/sgdn_Hd.csv')
sgdn_sgdn = pd.read_csv('test/logreg/+1e-03_+1e-03/sgdn_Hdmomentum.csv')
sgdn_adam = pd.read_csv('test/logreg/+1e-03_+1e-03/sgdn_HdAdam.csv')
sgdn = pd.read_csv('test/logreg/+1e-03_+1e-06/sgdn.csv')

adam = pd.read_csv('test/logreg/+1e-03_+1e-06/adam.csv')
adam_hd = pd.read_csv('test/logreg/+1e-03_+1e-07/adam_Hd.csv')
adam_adam = pd.read_csv('test/logreg/+1e-03_+1e-07/adam_HdAdam.csv')
adam_sgdn = pd.read_csv('test/logreg/+1e-03_+1e-07/adam_Hdmomentum.csv')

# %%
sgd_adam.head()
# Out:
#    Epoch  Iteration      Time      Loss  LossEpoch  ValidLossEpoch     Alpha  \
# 0      0          0  0.000000  2.197798   2.197798        2.285788  0.001000
# 1      1          1  0.035285  2.287352        NaN             NaN  0.001000
# 2      1          2  0.062239  2.367012        NaN             NaN  0.001744
# 3      1          3  0.088425  2.204499        NaN             NaN  0.002592
# 4      1          4  0.114034  2.225816        NaN             NaN  0.003492
#
#    AlphaEpoch   Beta
# 0       0.001  0.001
# 1         NaN  0.001
# 2         NaN  0.001
# 3         NaN  0.001
# 4         NaN  0.001

# %%
data = pd.DataFrame()
data['sgd'] = sgd['ValidLossEpoch']
data['sgd_HdAdam'] = sgd_adam['ValidLossEpoch']
data['sgd_Hd'] = sgd_hd['ValidLossEpoch']
data['sgd_Hdmomentum'] = sgd_sgdn['ValidLossEpoch']
data['sgdn_HdAdam'] = sgdn_adam['ValidLossEpoch']
data['sgdn_Hd'] = sgdn_hd['ValidLossEpoch']
data['sgdn_Hdmomentum'] = sgdn_sgdn['ValidLossEpoch']
data['sgdn'] = sgdn['ValidLossEpoch']
data['adam_HdAdam'] = adam_adam['ValidLossEpoch']
data['adam_Hdmomentum'] = adam_sgdn['ValidLossEpoch']
data['adam'] = adam['ValidLossEpoch']
data['adam_Hd'] = adam_hd['ValidLossEpoch']

# %%
data.head()
# Out:
#         sgd  sgd_HdAdam    sgd_Hd  sgd_Hdmomentum  sgdn_HdAdam   sgdn_Hd  \
# 0  2.285788    2.285788  2.285788        2.285788     2.285788  2.285788
# 1       NaN         NaN       NaN             NaN          NaN       NaN
# 2       NaN         NaN       NaN             NaN          NaN       NaN
# 3       NaN         NaN       NaN             NaN          NaN       NaN
# 4       NaN         NaN       NaN             NaN          NaN       NaN
#
#    sgdn_Hdmomentum      sgdn  adam_HdAdam  adam_Hdmomentum      adam   adam_Hd
# 0         2.285788  2.285788     2.285788         2.285788  2.285788  2.285788
# 1              NaN       NaN          NaN              NaN       NaN       NaN
# 2              NaN       NaN          NaN              NaN       NaN       NaN
# 3              NaN       NaN          NaN              NaN       NaN       NaN
# 4              NaN       NaN          NaN              NaN       NaN       NaN

# %%
data_ = data.dropna(axis=0, how='all')

# %%
data_.head()
# Out:
#            sgd  sgd_HdAdam    sgd_Hd  sgd_Hdmomentum  sgdn_HdAdam   sgdn_Hd  \
# 0     2.285788    2.285788  2.285788        2.285788     2.285788  2.285788
# 469   0.769226    0.323989  0.316285        0.342034     0.293982  0.286201
# 938   0.583714    0.302498  0.299395        0.319564     0.281270  0.277509
# 1407  0.508202    0.295410  0.293206        0.312912     0.271949  0.273482
# 1876  0.465842    0.293649  0.290807        0.305531     0.269826  0.273307
#
#       sgdn_Hdmomentum      sgdn  adam_HdAdam  adam_Hdmomentum      adam  \
# 0            2.285788  2.285788     2.285788         2.285788  2.285788
# 469          0.293920  0.373228     0.298360         0.286900  0.298398
# 938          0.281055  0.333106     0.282138         0.285144  0.282190
# 1407         0.279088  0.314978     0.275881         0.275485  0.275890
# 1876         0.277808  0.304999     0.279054         0.288250  0.279605
#
#        adam_Hd
# 0     2.285788
# 469   0.295049
# 938   0.281787
# 1407  0.275339
# 1876  0.281556

# %%
len(data_)
# Out:
# 21

# %%
a = list(data.columns)

# %%
a
# Out:
# ['sgd',
#  'sgd_HdAdam',
#  'sgd_Hd',
#  'sgd_Hdmomentum',
#  'sgdn_HdAdam',
#  'sgdn_Hd',
#  'sgdn_Hdmomentum',
#  'sgdn',
#  'adam_HdAdam',
#  'adam_Hdmomentum',
#  'adam',
#  'adam_Hd']

# %%
a
config = {}
config['sgd'] = {'c':'gold', 'linestyle':':'}
config['sgd_HdAdam'] = {'c':'darkred', 'linestyle':':'}
config['sgd_Hd'] = {'c':'black', 'linestyle':':'}
config['sgd_Hdmomentum'] = {'c':'blue', 'linestyle':':'}
config['sgdn_HdAdam'] = {'c':'green', 'linestyle':'--'}
config['sgdn_Hd'] = {'c':'teal', 'linestyle':'--'}
config['sgdn_Hdmomentum'] = {'c':'purple', 'linestyle':'--'}
config['sgdn'] = {'c':'gold', 'linestyle':'--'}
config['adam_HdAdam'] = {'c':'darkturquoise', 'linestyle':'-'}
config['adam_Hdmomentum'] = {'c':'lime','linestyle':'-'}
config['adam'] = {'c':'red', 'linestyle':'-'}
config['adam_Hd'] = {'c':'chocolate', 'linestyle':'-'} 
data_ = data_.reset_index()

# %%
plt.figure()
for optimizer in a:
    data_[optimizer].plot(color = config[optimizer]['c'], linestyle = config[optimizer]['linestyle'])
plt.legend(loc = 'best')
plt.xlabel('Epochs')
plt.ylabel('Validation Loss')
plt.ylim(top=0.4, bottom= 0.25)

fig = matplotlib.pyplot.gcf()
fig.set_size_inches(18.5, 10.5)

#plt.show()
plt.savefig('Logreg_Valid_Loss.pdf', bbox_inches='tight')

# %%
data_
# Out:
#     index  opSgd_lopAdam  opSgd_lopHd  opSgd_lopSgdn  opSgdn_lopAdam  \
