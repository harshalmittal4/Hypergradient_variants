# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_sgd_hd_adam = pd.read_csv('test2/logreg/+1e-03_+1e-03/sgd_hd_adam.csv')
df_sgd_hd_nag = pd.read_csv('test2/logreg/+1e-03_+1e-03/sgd_hd_nag.csv')
df_sgd_hd = pd.read_csv('test2/logreg/+1e-03_+1e-03/sgd_hd.csv')
df_sgd = pd.read_csv('test2/logreg/+1e-03_+1e-03/sgd.csv')

# %%
df_sgd_hd_adam.head()
# Out:
#    Epoch  Iteration      Time                             Loss  \
# 0      0          0  0.000000  tensor(2.1978, device='cuda:0')
# 1      1          1  0.040217  tensor(2.2874, device='cuda:0')
# 2      1          2  0.066995  tensor(2.3559, device='cuda:0')
# 3      1          3  0.094043  tensor(2.1592, device='cuda:0')
# 4      1          4  0.121552  tensor(2.1062, device='cuda:0')
#
#                          LossEpoch                   ValidLossEpoch  \
# 0  tensor(2.1978, device='cuda:0')  tensor(2.2858, device='cuda:0')
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#                              Alpha AlphaEpoch   Beta
# 0                            0.001      0.001  0.001
# 1                            0.001        NaN  0.001
# 2  tensor(0.0017, device='cuda:0')        NaN  0.001
# 3  tensor(0.0026, device='cuda:0')        NaN  0.001
# 4  tensor(0.0035, device='cuda:0')        NaN  0.001

# %%
df_sgd_hd_nag.head()
# Out:
#    Epoch  Iteration      Time                             Loss  \
# 0      0          0  0.000000  tensor(2.1978, device='cuda:0')
# 1      1          1  0.034040  tensor(2.2874, device='cuda:0')
# 2      1          2  0.063010  tensor(2.3559, device='cuda:0')
# 3      1          3  0.090765  tensor(1.6821, device='cuda:0')
# 4      1          4  0.121194  tensor(1.4429, device='cuda:0')
#
#                          LossEpoch                   ValidLossEpoch  \
# 0  tensor(2.1978, device='cuda:0')  tensor(2.2858, device='cuda:0')
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#                              Alpha AlphaEpoch   Beta
# 0                            0.001      0.001  0.001
# 1  tensor(0.0010, device='cuda:0')        NaN  0.001
# 2  tensor(0.0243, device='cuda:0')        NaN  0.001
# 3  tensor(0.0577, device='cuda:0')        NaN  0.001
# 4  tensor(0.0765, device='cuda:0')        NaN  0.001

# %%
df_sgd_hd.head()
# Out:
#    Epoch  Iteration      Time                             Loss  \
# 0      0          0  0.000000  tensor(2.1978, device='cuda:0')
# 1      1          1  0.034688  tensor(2.2874, device='cuda:0')
# 2      1          2  0.063679  tensor(2.3670, device='cuda:0')
# 3      1          3  0.092361  tensor(2.0953, device='cuda:0')
# 4      1          4  0.120307  tensor(1.9259, device='cuda:0')
#
#                          LossEpoch                   ValidLossEpoch  \
# 0  tensor(2.1978, device='cuda:0')  tensor(2.2858, device='cuda:0')
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#                              Alpha AlphaEpoch   Beta
# 0                            0.001      0.001  0.001
# 1  tensor(0.0010, device='cuda:0')        NaN  0.001
# 2  tensor(0.0134, device='cuda:0')        NaN  0.001
# 3  tensor(0.0223, device='cuda:0')        NaN  0.001
# 4  tensor(0.0288, device='cuda:0')        NaN  0.001

# %%
df_sgd.head()
# Out:
#    Epoch  Iteration      Time                             Loss  \
# 0      0          0  0.000000  tensor(2.1978, device='cuda:0')
# 1      1          1  0.033663  tensor(2.2874, device='cuda:0')
# 2      1          2  0.059612  tensor(2.3670, device='cuda:0')
# 3      1          3  0.089947  tensor(2.2118, device='cuda:0')
# 4      1          4  0.121221  tensor(2.2522, device='cuda:0')
#
#                          LossEpoch                   ValidLossEpoch  Alpha  \
# 0  tensor(2.1978, device='cuda:0')  tensor(2.2858, device='cuda:0')  0.001
# 1                              NaN                              NaN  0.001
# 2                              NaN                              NaN  0.001
# 3                              NaN                              NaN  0.001
# 4                              NaN                              NaN  0.001
#
#    AlphaEpoch   Beta
# 0       0.001  0.001
# 1         NaN  0.001
# 2         NaN  0.001
# 3         NaN  0.001
# 4         NaN  0.001

# %%
float(df_sgd['Alpha'][1])
# Out:
# 0.001

# %%
iteration = []
loss_sgd_hd_adam = []
loss_sgd_hd_nag = []
loss_sgd_hd = []
loss_sgd = []
alpha_sgd_hd_adam = []
alpha_sgd_hd_nag = []
alpha_sgd_hd = []
alpha_sgd = []

for i in range(max(len(df_sgd_hd_adam),len(df_sgd_hd_nag),len(df_sgd_hd), len(df_sgd))):
    if i % 10 == 0:
        try:
            iteration.append(int(df_sgd_hd_adam['Iteration'][i]))
            loss_sgd_hd_adam.append(float(df_sgd_hd_adam['Loss'][i][7:-18]))
            if df_sgd_hd_adam['Alpha'][i].find('tensor') < 0:
                alpha_sgd_hd_adam.append(float(df_sgd_hd_adam['Alpha'][i]))
            else:
                alpha_sgd_hd_adam.append(float(df_sgd_hd_adam['Alpha'][i][7:-18]))

            loss_sgd_hd_nag.append(float(df_sgd_hd_nag['Loss'][i][7:-18]))
            if df_sgd_hd_nag['Alpha'][i].find('tensor') < 0:
                alpha_sgd_hd_nag.append(float(df_sgd_hd_nag['Alpha'][i]))
            else:
                alpha_sgd_hd_nag.append(float(df_sgd_hd_nag['Alpha'][i][7:-18]))

            loss_sgd_hd.append(float(df_sgd_hd['Loss'][i][7:-18]))
            if df_sgd_hd['Alpha'][i].find('tensor') < 0:
                alpha_sgd_hd.append(float(df_sgd_hd['Alpha'][i]))
            else:
                alpha_sgd_hd.append(float(df_sgd_hd['Alpha'][i][7:-18]))

            loss_sgd.append(float(df_sgd['Loss'][i][7:-18]))
            alpha_sgd.append(float(df_sgd['Alpha'][i]))

        except:
            continue

# %%
print(len(iteration))
print(len(alpha_sgd))
# Out:
# 939
# 939

# %%
plt.figure(figsize=(50,25))
plt.plot(iteration, loss_sgd_hd_adam, color='red', label='sgd_hd_adam')
plt.plot(iteration, loss_sgd_hd_nag, color='blue', label='sgd_hd_nag')
plt.plot(iteration, loss_sgd_hd, color='green', label='sgd_hd')
plt.plot(iteration, loss_sgd, color='black', label='sgd')
plt.legend(loc='best')
plt.savefig('HDplots/loss.png')

# %%
plt.figure(figsize=(50,25))
plt.plot(iteration, alpha_sgd_hd_adam, color='red', label='sgd_hd_adam')
plt.plot(iteration, alpha_sgd_hd_nag, color='blue', label='sgd_hd_nag')
plt.plot(iteration, alpha_sgd_hd, color='green', label='sgd_hd')
plt.plot(iteration, alpha_sgd, color='black', label='sgd')
plt.legend(loc='best')
plt.savefig('HDplots/alpha.png')
